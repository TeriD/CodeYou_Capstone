# %%
import os

# %%
if __name__ == '__main__':
    # Save the script name in a variable
    script_name = 'workzone_dashboard.py'

    # Run the `panel serve` command using os.system
    os.system(f'panel serve {script_name} --show')
# Out:
# 2024-08-05 15:30:33,938 Starting Bokeh server version 3.4.2 (running on Tornado 6.4.1)
# 2024-08-05 15:30:33,938 User authentication hooks NOT provided (default user enabled)
# 2024-08-05 15:30:33,941 Bokeh app running at: http://localhost:5006/workzone_dashboard
# 2024-08-05 15:30:33,941 Starting Bokeh server with process id: 54656
# WARNING:param.HTML: Providing a height-responsive sizing_mode ('stretch_both') and a fixed height is not supported. Converting fixed height to min_height. If you intended the component to be fully height-responsive remove the height setting, otherwise change it to min_height. To error on the incorrect specification disable the config.layout_compatibility option.
# ...
